# %%
import pandas as pd

# %%
n1=pd.read_excel("2023BigFesta_NewsDataset_202301_1.xlsx")
n2=pd.read_excel("2023BigFesta_NewsDataset_202301_2.xlsx")
n3=pd.read_excel("2023BigFesta_NewsDataset_202301_3.xlsx")
n4=pd.read_excel("2023BigFesta_NewsDataset_202301_4.xlsx")
n5=pd.read_excel("2023BigFesta_NewsDataset_202301_5.xlsx")
n6=pd.read_excel("2023BigFesta_NewsDataset_202302_1.xlsx")
n7=pd.read_excel("2023BigFesta_NewsDataset_202302_2.xlsx")
n8=pd.read_excel("2023BigFesta_NewsDataset_202302_3.xlsx")
n9=pd.read_excel("2023BigFesta_NewsDataset_202302_4.xlsx")
n10=pd.read_excel("2023BigFesta_NewsDataset_202302_5.xlsx")
n11=pd.read_excel("2023BigFesta_NewsDataset_202303_1.xlsx")
n12=pd.read_excel("2023BigFesta_NewsDataset_202303_2.xlsx")
n13=pd.read_excel("2023BigFesta_NewsDataset_202303_3.xlsx")
n14=pd.read_excel("2023BigFesta_NewsDataset_202303_4.xlsx")
n15=pd.read_excel("2023BigFesta_NewsDataset_202303_5.xlsx")
n16=pd.read_excel("2023BigFesta_NewsDataset_202304_1.xlsx")
n17=pd.read_excel("2023BigFesta_NewsDataset_202304_2.xlsx")
n18=pd.read_excel("2023BigFesta_NewsDataset_202304_3.xlsx")
n19=pd.read_excel("2023BigFesta_NewsDataset_202304_4.xlsx")
n20=pd.read_excel("2023BigFesta_NewsDataset_202304_5.xlsx")
n21=pd.read_excel("2023BigFesta_NewsDataset_202305_1.xlsx")
n22=pd.read_excel("2023BigFesta_NewsDataset_202305_2.xlsx")
n23=pd.read_excel("2023BigFesta_NewsDataset_202305_3.xlsx")
n24=pd.read_excel("2023BigFesta_NewsDataset_202305_4.xlsx")
n25=pd.read_excel("2023BigFesta_NewsDataset_202305_5.xlsx")
n26=pd.read_excel("2023BigFesta_NewsDataset_202306_1.xlsx")
n27=pd.read_excel("2023BigFesta_NewsDataset_202306_2.xlsx")
n28=pd.read_excel("2023BigFesta_NewsDataset_202306_3.xlsx")
n29=pd.read_excel("2023BigFesta_NewsDataset_202306_4.xlsx")
n30=pd.read_excel("2023BigFesta_NewsDataset_202306_5.xlsx")

# %%
n1=n1.iloc[:, [2,5,6,7,9]]

# %%
n1=n1.dropna(subset=['ITEM_NAME'])

# %%
n2=n2.iloc[:, [2,5,6,7,9]]
n2=n2.dropna(subset=['ITEM_NAME'])

n3=n3.iloc[:, [2,5,6,7,9]]
n3=n3.dropna(subset=['ITEM_NAME'])

n4=n4.iloc[:, [2,5,6,7,9]]
n4=n4.dropna(subset=['ITEM_NAME'])

n5=n5.iloc[:, [2,5,6,7,9]]
n5=n5.dropna(subset=['ITEM_NAME'])

n6=n6.iloc[:, [2,5,6,7,9]]
n6=n6.dropna(subset=['ITEM_NAME'])

n7=n7.iloc[:, [2,5,6,7,9]]
n7=n7.dropna(subset=['ITEM_NAME'])

n8=n8.iloc[:, [2,5,6,7,9]]
n8=n8.dropna(subset=['ITEM_NAME'])

n9=n9.iloc[:, [2,5,6,7,9]]
n9=n9.dropna(subset=['ITEM_NAME'])

n10=n10.iloc[:, [2,5,6,7,9]]
n10=n10.dropna(subset=['ITEM_NAME'])

n11=n11.iloc[:, [2,5,6,7,9]]
n11=n11.dropna(subset=['ITEM_NAME'])

n12=n12.iloc[:, [2,5,6,7,9]]
n12=n12.dropna(subset=['ITEM_NAME'])

n13=n13.iloc[:, [2,5,6,7,9]]
n13=n13.dropna(subset=['ITEM_NAME'])

n14=n14.iloc[:, [2,5,6,7,9]]
n14=n14.dropna(subset=['ITEM_NAME'])

n15=n15.iloc[:, [2,5,6,7,9]]
n15=n15.dropna(subset=['ITEM_NAME'])

n16=n16.iloc[:, [2,5,6,7,9]]
n16=n16.dropna(subset=['ITEM_NAME'])

n17=n17.iloc[:, [2,5,6,7,9]]
n17=n17.dropna(subset=['ITEM_NAME'])

n18=n18.iloc[:, [2,5,6,7,9]]
n18=n18.dropna(subset=['ITEM_NAME'])

n19=n19.iloc[:, [2,5,6,7,9]]
n19=n19.dropna(subset=['ITEM_NAME'])

n20=n20.iloc[:, [2,5,6,7,9]]
n20=n20.dropna(subset=['ITEM_NAME'])

n21=n21.iloc[:, [2,5,6,7,9]]
n21=n21.dropna(subset=['ITEM_NAME'])

n22=n22.iloc[:, [2,5,6,7,9]]
n22=n22.dropna(subset=['ITEM_NAME'])

n23=n23.iloc[:, [2,5,6,7,9]]
n23=n23.dropna(subset=['ITEM_NAME'])

n24=n24.iloc[:, [2,5,6,7,9]]
n24=n24.dropna(subset=['ITEM_NAME'])

n25=n25.iloc[:, [2,5,6,7,9]]
n25=n25.dropna(subset=['ITEM_NAME'])

n26=n26.iloc[:, [2,5,6,7,9]]
n26=n26.dropna(subset=['ITEM_NAME'])

n27=n27.iloc[:, [2,5,6,7,9]]
n27=n27.dropna(subset=['ITEM_NAME'])

n28=n28.iloc[:, [2,5,6,7,9]]
n28=n28.dropna(subset=['ITEM_NAME'])

n29=n29.iloc[:, [2,5,6,7,9]]
n29=n29.dropna(subset=['ITEM_NAME'])

n30=n30.iloc[:, [2,5,6,7,9]]
n30=n30.dropna(subset=['ITEM_NAME'])

# %%
aa=pd.concat([n1, n2,n3,n4,n5,n6,n7,n8,n9,n10,n11,n12,n13,n14,n15,n16,n17,n18,n19,n20,n21,n22,n23,n24,n25,n26,n27,n28,n29,n30])

# %%
aa
# Out:
#               DATE_TIME                                              TITLE  \
# 3       20230101_070300                   "이미 모든 악재 나왔다"…전문가가 뽑은 내년 뜰 업종은?
# 21      20230102_054500        CES엔 대기업만 있나?…'삼성 C랩·LG NOVA' 톡톡 튀는 스타트업 향연
# 37      20230102_095413                 CBI "지난해 최대 매출 기대…올해도 기록적인 성장세 전망"
# 38      20230102_101911           드래곤플라이, 베이스크림 힙합 뮤지션과 OST 제작에 나서…MZ세대 공략
# 41      20230102_103126               장덕현 삼성전기 사장 "강한 사업체질 구축 필요…새 기회 잡아야"
# ...                 ...                                                ...
# 172273  20230623_082039               [투데이리포트]삼성전자, "4분기 HBM3 공…" BUY-KB증권
# 172274  20230623_082238                    [투데이리포트]아모레퍼시픽, "기다림…" BUY-키움증권
# 172275  20230623_084835            [투데이리포트]선진뷰티사이언스, "안정성과 성장성을 …" -신한투자증권
# 172276  20230623_102230         [디케이티 지분 변동] 파로스자산운용(주)6.32%p 증가, 6.32% 보유
# 172277  20230623_131654  [Live팩트 리포트] HJ중공업(097230) 수주ㆍ공급계약 - "한국전력공사과 ...
#
#         IMPORTANCE  ITEM_NAME  \
# 3            58.26    고려아연|영풍
# ...

# %%
aa=aa.drop_duplicates()

# %%
aa
# Out:
#               DATE_TIME                                              TITLE  \
# 3       20230101_070300                   "이미 모든 악재 나왔다"…전문가가 뽑은 내년 뜰 업종은?
# 21      20230102_054500        CES엔 대기업만 있나?…'삼성 C랩·LG NOVA' 톡톡 튀는 스타트업 향연
# 37      20230102_095413                 CBI "지난해 최대 매출 기대…올해도 기록적인 성장세 전망"
# 38      20230102_101911           드래곤플라이, 베이스크림 힙합 뮤지션과 OST 제작에 나서…MZ세대 공략
# 41      20230102_103126               장덕현 삼성전기 사장 "강한 사업체질 구축 필요…새 기회 잡아야"
# ...                 ...                                                ...
# 172273  20230623_082039               [투데이리포트]삼성전자, "4분기 HBM3 공…" BUY-KB증권
# 172274  20230623_082238                    [투데이리포트]아모레퍼시픽, "기다림…" BUY-키움증권
# 172275  20230623_084835            [투데이리포트]선진뷰티사이언스, "안정성과 성장성을 …" -신한투자증권
# 172276  20230623_102230         [디케이티 지분 변동] 파로스자산운용(주)6.32%p 증가, 6.32% 보유
# 172277  20230623_131654  [Live팩트 리포트] HJ중공업(097230) 수주ㆍ공급계약 - "한국전력공사과 ...
#
#         IMPORTANCE  ITEM_NAME  \
# 3            58.26    고려아연|영풍
# ...

# %%
import pandas as pd
import os

# %%
os.chdir('C:/Users/horri/Desktop/대외활동/비어플/미래에셋 공모전/뉴스 데이터')

# %%
aa.to_csv('inte.csv',index=False)
